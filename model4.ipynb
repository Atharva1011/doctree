# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv("./datasets/Doceree-HCP_Train.csv", encoding="latin-1")
test_x_df = pd.read_csv("./datasets/Doceree-HCP-Test.csv", encoding="latin-1")
test_y_df = pd.read_csv("./datasets/Doceree_HCP_Sample_Submission_1.csv", encoding="latin-1")

# %%
train_df
# Out:
#             ID DEVICETYPE  PLATFORM_ID    BIDREQUESTIP  \
# 0         1001    Desktop            2    170.173.0.22
# 1         1002    Desktop            2   65.216.253.25
# 2         1003    Desktop            2    66.232.79.22
# 3         1004    Desktop            3  137.54.125.246
# 4         1005     Mobile            7  174.202.231.99
# ...        ...        ...          ...             ...
# 113932  114933    Desktop            2    68.82.97.126
# 113933  114934    Desktop            2  104.172.11.109
# 113934  114935    Desktop            7   174.21.94.113
# 113935  114936     Mobile            2  69.253.129.131
# 113936  114937     Mobile            2  108.41.233.175
#
#                              USERPLATFORMUID      USERCITY  USERZIPCODE  \
# 0       6974dcaa-f932-480e-9fb5-c52e20e1393a      Portland      97206.0
# 1       c12f3f8f-8fcf-484a-90e1-1ac04db8cdcf     Arlington      22202.0
# 2       a698de4b-e200-46dd-b5fb-40402175ae18   New Meadows      83654.0
# ...

# %%
test_x_df
# Out:
#            ID DEVICETYPE  PLATFORM_ID     BIDREQUESTIP  \
# 0      115501    Desktop          2.0   75.189.231.103
# 1      115502     Mobile          2.0    24.101.33.158
# 2      115503    Desktop          2.0  172.118.216.142
# 3      115504    Desktop          7.0   71.105.120.171
# 4      115505    Desktop          2.0     73.82.211.73
# ...       ...        ...          ...              ...
# 28575  144026    Desktop          2.0   69.202.233.241
# 28576  144027    Desktop          7.0      75.4.190.65
# 28577  144028    Desktop          7.0    137.52.180.45
# 28578  144029    Desktop          8.0      66.249.66.4
# 28579  144030    Desktop          2.0   107.194.33.149
#
#                             USERPLATFORMUID         USERCITY  USERZIPCODE  \
# 0      0d5041ff-f0b6-4d1a-9ad7-0a29f7d485b4     Fayetteville      28305.0
# 1      c8396dd0-969f-4d99-a40b-b7bb1f516154    Conneaut Lake      16316.0
# 2      3c97a081-6518-43f8-9f26-369759cfb471           Covina      91724.0
# ...

# %%
test_y_df
# Out:
#           ID    TAXONOMY  IS_HCP
# 0          1         NaN       0
# 1          2  2084P0800X       1
# 2          3         NaN       0
# 3          4         NaN       0
# 4          5         NaN       0
# ...      ...         ...     ...
# 28525  28526         NaN       0
# 28526  28527         NaN       0
# 28527  28528         NaN       0
# 28528  28529         NaN       0
# 28529  28530         NaN       0
#
# [28530 rows x 3 columns]

# %%
test_df = pd.concat([test_x_df, test_y_df], axis=1)

# %%
test_df
# Out:
#            ID DEVICETYPE  PLATFORM_ID     BIDREQUESTIP  \
# 0      115501    Desktop          2.0   75.189.231.103
# 1      115502     Mobile          2.0    24.101.33.158
# 2      115503    Desktop          2.0  172.118.216.142
# 3      115504    Desktop          7.0   71.105.120.171
# 4      115505    Desktop          2.0     73.82.211.73
# ...       ...        ...          ...              ...
# 28575  144026    Desktop          2.0   69.202.233.241
# 28576  144027    Desktop          7.0      75.4.190.65
# 28577  144028    Desktop          7.0    137.52.180.45
# 28578  144029    Desktop          8.0      66.249.66.4
# 28579  144030    Desktop          2.0   107.194.33.149
#
#                             USERPLATFORMUID         USERCITY  USERZIPCODE  \
# 0      0d5041ff-f0b6-4d1a-9ad7-0a29f7d485b4     Fayetteville      28305.0
# 1      c8396dd0-969f-4d99-a40b-b7bb1f516154    Conneaut Lake      16316.0
# 2      3c97a081-6518-43f8-9f26-369759cfb471           Covina      91724.0
# ...

# %%
# dropping unwanted columns

# %%
train_df.drop(columns=["USERPLATFORMUID", "CHANNELTYPE", "ID"], inplace=True)

# %%
test_df.drop(columns=["USERPLATFORMUID", "CHANNELTYPE", "ID"], inplace=True)

# %%
test_df
# Out:
#       DEVICETYPE  PLATFORM_ID     BIDREQUESTIP         USERCITY  USERZIPCODE  \
# 0        Desktop          2.0   75.189.231.103     Fayetteville      28305.0
# 1         Mobile          2.0    24.101.33.158    Conneaut Lake      16316.0
# 2        Desktop          2.0  172.118.216.142           Covina      91724.0
# 3        Desktop          7.0   71.105.120.171         Brooklyn      11226.0
# 4        Desktop          2.0     73.82.211.73         Marietta      30062.0
# ...          ...          ...              ...              ...          ...
# 28575    Desktop          2.0   69.202.233.241         Brooklyn      11215.0
# 28576    Desktop          7.0      75.4.190.65            Miami      33178.0
# 28577    Desktop          7.0    137.52.180.45  Fort Lauderdale      33314.0
# 28578    Desktop          8.0      66.249.66.4              NaN          NaN
# 28579    Desktop          2.0   107.194.33.149       Wilmington      28412.0
#
# ...

# %%
train_df
# Out:
#        DEVICETYPE  PLATFORM_ID    BIDREQUESTIP      USERCITY  USERZIPCODE  \
# 0         Desktop            2    170.173.0.22      Portland      97206.0
# 1         Desktop            2   65.216.253.25     Arlington      22202.0
# 2         Desktop            2    66.232.79.22   New Meadows      83654.0
# 3         Desktop            3  137.54.125.246           NaN  229114624.0
# 4          Mobile            7  174.202.231.99       Houston      77008.0
# ...           ...          ...             ...           ...          ...
# 113932    Desktop            2    68.82.97.126  Philadelphia      19120.0
# 113933    Desktop            2  104.172.11.109      Van Nuys  914014213.0
# 113934    Desktop            7   174.21.94.113           NaN      98105.0
# 113935     Mobile            2  69.253.129.131    Wilmington      19808.0
# 113936     Mobile            2  108.41.233.175  White Plains      10605.0
#
#                                                 USERAGENT  \
# ...

# %%
train_df.isna().sum()
# Out:
# DEVICETYPE          0
# PLATFORM_ID         0
# BIDREQUESTIP        0
# USERCITY         6359
# USERZIPCODE      4592
# USERAGENT           2
# PLATFORMTYPE        0
# URL                 0
# KEYWORDS            0
# TAXONOMY        81624
# IS_HCP              1
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# DEVICETYPE         30
# PLATFORM_ID        50
# BIDREQUESTIP       50
# USERCITY         1644
# USERZIPCODE      1200
# USERAGENT          51
# PLATFORMTYPE       50
# URL                50
# KEYWORDS           70
# TAXONOMY        28579
# IS_HCP             50
# dtype: int64

# %%
train_df.shape
# Out:
# (113937, 11)

# %%
test_df.shape
# Out:
# (28580, 11)

# %%
train_df.drop(columns=["TAXONOMY"], inplace=True)

# %%
test_df.drop(columns=["TAXONOMY"], inplace=True)

# %%
test_df.isna().sum()
# Out:
# DEVICETYPE        30
# PLATFORM_ID       50
# BIDREQUESTIP      50
# USERCITY        1644
# USERZIPCODE     1200
# USERAGENT         51
# PLATFORMTYPE      50
# URL               50
# KEYWORDS          70
# IS_HCP            50
# dtype: int64

# %%
test_df.dropna(inplace=True)

# %%
test_df.shape
# Out:
# (26886, 10)

# %%
train_df.shape
# Out:
# (113937, 10)

# %%
test_df.isna().sum()
# Out:
# DEVICETYPE      0
# PLATFORM_ID     0
# BIDREQUESTIP    0
# USERCITY        0
# USERZIPCODE     0
# USERAGENT       0
# PLATFORMTYPE    0
# URL             0
# KEYWORDS        0
# IS_HCP          0
# dtype: int64

# %%
train_df.isna().sum()
# Out:
# DEVICETYPE         0
# PLATFORM_ID        0
# BIDREQUESTIP       0
# USERCITY        6359
# USERZIPCODE     4592
# USERAGENT          2
# PLATFORMTYPE       0
# URL                0
# KEYWORDS           0
# IS_HCP             1
# dtype: int64

# %%
train_df.dropna(inplace=True)

# %%
train_df.shape
# Out:
# (107574, 10)

# %%
train_df.isna().sum()
# Out:
# DEVICETYPE      0
# PLATFORM_ID     0
# BIDREQUESTIP    0
# USERCITY        0
# USERZIPCODE     0
# USERAGENT       0
# PLATFORMTYPE    0
# URL             0
# KEYWORDS        0
# IS_HCP          0
# dtype: int64

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107574 entries, 0 to 113936
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   DEVICETYPE    107574 non-null  object
#  1   PLATFORM_ID   107574 non-null  int64
#  2   BIDREQUESTIP  107574 non-null  object
#  3   USERCITY      107574 non-null  object
#  4   USERZIPCODE   107574 non-null  float64
#  5   USERAGENT     107574 non-null  object
#  6   PLATFORMTYPE  107574 non-null  object
#  7   URL           107574 non-null  object
#  8   KEYWORDS      107574 non-null  object
#  9   IS_HCP        107574 non-null  float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 9.0+ MB

# %%
train_df.describe()
# Out:
#          PLATFORM_ID   USERZIPCODE         IS_HCP
# count  107574.000000  1.075740e+05  107574.000000
# mean        3.419851  1.170641e+07       0.300798
# std         2.463466  8.541401e+07       0.458607
# min         1.000000  6.020000e+02       0.000000
# 25%         2.000000  1.914400e+04       0.000000
# 50%         2.000000  4.212450e+04       0.000000
# 75%         5.000000  7.700500e+04       1.000000
# max        15.000000  9.970149e+08       1.000000

# %%
train_df.drop(columns=["BIDREQUESTIP"], inplace=True)

# %%
test_df.drop(columns=["BIDREQUESTIP"], inplace=True)

# %%
train_df
# Out:
#        DEVICETYPE  PLATFORM_ID      USERCITY  USERZIPCODE  \
# 0         Desktop            2      Portland      97206.0
# 1         Desktop            2     Arlington      22202.0
# 2         Desktop            2   New Meadows      83654.0
# 4          Mobile            7       Houston      77008.0
# 5         Desktop            7      Syracuse      13215.0
# ...           ...          ...           ...          ...
# 113931     Mobile            2         Plano      75074.0
# 113932    Desktop            2  Philadelphia      19120.0
# 113933    Desktop            2      Van Nuys  914014213.0
# 113935     Mobile            2    Wilmington      19808.0
# 113936     Mobile            2  White Plains      10605.0
#
#                                                 USERAGENT  \
# 0       Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 1       Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 2       Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# ...

# %%
# !pip install geopy

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="geoapiExercises")
location = geolocator.geocode("19120.0")
print(str(location).split(",")[-1])
# Out:
#  Algeria

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="geoapiExercises")
def getCountry(code):
    location = geolocator.geocode(str(code))
    return str(location).split(",")[-1]

# %%
import re
def getHostName(url):
    match = re.match(r"^(?:https?:\/\/)?(?:[^@\n]+@)?(?:www\.)?([^:\/\n]+)", url)
    if match:
        host_name = match.group(1)
        return host_name

# %%
train_df["HOSTNAME"] = train_df["URL"].apply(getHostName)

# %%
train_df["HOSTNAME"] = train_df["HOSTNAME"].apply(lambda x: x.split(".")[0])

# %%
train_df.drop(columns=["URL"], inplace=True)

# %%
train_df
# Out:
#        DEVICETYPE  PLATFORM_ID      USERCITY  USERZIPCODE  \
# 0         Desktop            2      Portland      97206.0
# 1         Desktop            2     Arlington      22202.0
# 2         Desktop            2   New Meadows      83654.0
# 4          Mobile            7       Houston      77008.0
# 5         Desktop            7      Syracuse      13215.0
# ...           ...          ...           ...          ...
# 113931     Mobile            2         Plano      75074.0
# 113932    Desktop            2  Philadelphia      19120.0
# 113933    Desktop            2      Van Nuys  914014213.0
# 113935     Mobile            2    Wilmington      19808.0
# 113936     Mobile            2  White Plains      10605.0
#
#                                                 USERAGENT  \
# 0       Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 1       Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 2       Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# ...

# %%
test_df["HOSTNAME"] = test_df["URL"].apply(getHostName)

# %%
test_df["HOSTNAME"] = test_df["HOSTNAME"].apply(lambda x: x.split(".")[0])

# %%
test_df.drop(columns=["URL"], inplace=True)

# %%
test_df
# Out:
#       DEVICETYPE  PLATFORM_ID            USERCITY  USERZIPCODE  \
# 0        Desktop          2.0        Fayetteville      28305.0
# 1         Mobile          2.0       Conneaut Lake      16316.0
# 2        Desktop          2.0              Covina      91724.0
# 3        Desktop          7.0            Brooklyn      11226.0
# 4        Desktop          2.0            Marietta      30062.0
# ...          ...          ...                 ...          ...
# 28525     Mobile          6.0  Saint Clair Shores      48082.0
# 28526    Desktop          2.0        Mount Laurel       8054.0
# 28527    Desktop          2.0         Los Angeles      90066.0
# 28528    Desktop          2.0            St Louis      63169.0
# 28529    Desktop          2.0             Houston      77055.0
#
#                                                USERAGENT  \
# 0      Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6...
# 1      Mozilla/5.0 (iPhone; CPU iPhone OS 15_6_1 like...
# ...

# %%
test_df.isna().sum()
# Out:
# DEVICETYPE      0
# PLATFORM_ID     0
# USERCITY        0
# USERZIPCODE     0
# USERAGENT       0
# PLATFORMTYPE    0
# KEYWORDS        0
# IS_HCP          0
# HOSTNAME        0
# dtype: int64

# %%
train_df.isna().sum()
# Out:
# DEVICETYPE      0
# PLATFORM_ID     0
# USERCITY        0
# USERZIPCODE     0
# USERAGENT       0
# PLATFORMTYPE    0
# KEYWORDS        0
# IS_HCP          0
# HOSTNAME        0
# dtype: int64

# %%
train_df["KEYWORDS"]
# Out:
# 0         General|Endocrine|False|Medicine|Surgery|Urolo...
# 1         Bone Marrow|Radiography|Chronic|Oncology|Psych...
# 2         General|Endocrine|False|Medicine|Surgery|Urolo...
# 4         Critical Care|Emergency Medicine|General Pract...
# 5         small|covid|nephrology|radiology|preventive me...
#                                 ...
# 113931    Myopathies|Small|Rheumatoid|Psychiatry|Urology...
# 113932    Cardiovascular|Clinical|False|Male|Oncology|Ps...
# 113933    Asthma|Arthritis|General|Clinical|Diagnosis|Rh...
# 113935    pain|disease|autoimmune|multiple sclerosis|gra...
# 113936    Genetic|Large|Autoimmune|Health|False|Abortion...
# Name: KEYWORDS, Length: 107574, dtype: object

# %%
train_df["KEYWORDS"] = train_df["KEYWORDS"].apply(lambda x: x.split("|"))

# %%
ans = []
def get_unique(lst):
    for i in lst:
        if i not in ans:
            ans.append(i)

# %%
train_df["KEYWORDS"].apply(get_unique)
# Out:
# 0         None
# 1         None
# 2         None
# 4         None
# 5         None
#           ...
# 113931    None
# 113932    None
# 113933    None
# 113935    None
# 113936    None
# Name: KEYWORDS, Length: 107574, dtype: object

# %%
print(ans)
# Out:
# ['General', 'Endocrine', 'False', 'Medicine', 'Surgery', 'Urology', 'Chronic', 'Gastroenterology', 'Neurology', 'Physicians', 'Diagnosis', 'Psychiatry', 'Lung', 'Clinical', 'Dermatology', 'Ophthalmology', 'Cardiovascular', 'Cardiology', 'Oncology', 'Rheumatology', 'Bone Marrow', 'Radiography', 'Intestine', 'Small Intestines', 'Salivary Glands', 'Autoimmune', 'Hemolytic', 'Hereditary', 'Total', 'Dendritic Cells', 'Biopsy', 'Large', 'Small', 'Lymphoid Tissue', 'B-Lymphocytes', 'Stomach', 'Transplantation', 'Gastrointestinal Tract', 'Intestines', 'Anemia', 'Refractory', 'Critical Care', 'Emergency Medicine', 'General Practice', 'Asthma', 'Neurological Surgery', 'Preventive', 'Trauma', 'Pathology', 'Nuclear Medicine', 'Orthopedics', 'Specialties', 'Technology', 'Resuscitation', 'Controlled', 'Respiratory Tract', 'Otolaryngology', 'Monocytes', 'Surgical', 'Aged', 'Rehabilitation', 'Molecular', 'Anesthesiology', 'Pediatrics', 'Newborn', 'Pancreas', 'Cardiac', 'Premature', 'Reproductive', '
# ...

# %%
import nltk
from nltk.stem import PorterStemmer
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/atharvadeshmukh/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
ps = PorterStemmer()

# %%
stemmed_words = []

# %%
for i in ans:
    stemmed_word = ps.stem(i)
    if stemmed_word not in stemmed_words:
        stemmed_words.append(stemmed_word)

# %%
stemmed_words
# Out:
# ['gener',
#  'endocrin',
#  'fals',
#  'medicin',
#  'surgeri',
#  'urolog',
#  'chronic',
#  'gastroenterolog',
#  'neurolog',
#  'physician',
#  'diagnosi',
#  'psychiatri',
#  'lung',
#  'clinic',
#  'dermatolog',
#  'ophthalmolog',
#  'cardiovascular',
#  'cardiolog',
#  'oncolog',
#  'rheumatolog',
#  'bone marrow',
#  'radiographi',
#  'intestin',
#  'small intestin',
#  'salivary gland',
#  'autoimmun',
#  'hemolyt',
#  'hereditari',
#  'total',
#  'dendritic cel',
#  'biopsi',
#  'larg',
#  'small',
#  'lymphoid tissu',
#  'b-lymphocyt',
#  'stomach',
#  'transplant',
#  'gastrointestinal tract',
#  'anemia',
#  'refractori',
#  'critical car',
#  'emergency medicin',
#  'general practic',
#  'asthma',
#  'neurological surgeri',
#  'prevent',
#  'trauma',
#  'patholog',
#  'nuclear medicin',
#  'orthoped',
#  'specialti',
#  'technolog',
#  'resuscit',
#  'control',
#  'respiratory tract',
#  'otolaryngolog',
#  'monocyt',
#  'surgic',
#  'age',
#  'rehabilit',
# ...

# %%
len(stemmed_words)
# Out:
# 1137

# %%
train_df["KEYWORDS"]
# Out:
# 0         [General, Endocrine, False, Medicine, Surgery,...
# 1         [Bone Marrow, Radiography, Chronic, Oncology, ...
# 2         [General, Endocrine, False, Medicine, Surgery,...
# 4         [Critical Care, Emergency Medicine, General Pr...
# 5         [small, covid, nephrology, radiology, preventi...
#                                 ...
# 113931    [Myopathies, Small, Rheumatoid, Psychiatry, Ur...
# 113932    [Cardiovascular, Clinical, False, Male, Oncolo...
# 113933    [Asthma, Arthritis, General, Clinical, Diagnos...
# 113935    [pain, disease, autoimmune, multiple sclerosis...
# 113936    [Genetic, Large, Autoimmune, Health, False, Ab...
# Name: KEYWORDS, Length: 107574, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
sample = train_df["KEYWORDS"].apply(lambda x: " ".join(x))
x_sample = vectorizer.fit_transform(sample)

# %%
print(x_sample)
# Out:
#   (0, 966)	0.18408339195491616
#   (0, 790)	0.15809998566095704
#   (0, 179)	0.1522201209918337
#   (0, 185)	0.26342295126513604
#   (0, 794)	0.18558635970111934
#   (0, 301)	0.15634530955933504
#   (0, 222)	0.14544049416000518
#   (0, 647)	0.34444500079009105
#   (0, 921)	0.1813208335872043
#   (0, 306)	0.22928767016312954
#   (0, 862)	0.37221443371429414
#   (0, 750)	0.18003945831820647
#   (0, 448)	0.1842047505327934
#   (0, 215)	0.24752693516334437
#   (0, 1142)	0.14808212941716284
#   (0, 1057)	0.2199950488737356
#   (0, 682)	0.15179750920782417
#   (0, 415)	0.1741233088154825
#   (0, 376)	0.38428067631418816
#   (0, 450)	0.16402927061953756
#   (1, 946)	0.13068302277122532
#   (1, 48)	0.1396558804066997
#   (1, 1108)	0.13045930405421163
#   (1, 449)	0.19696494448466653
#   (1, 1119)	0.0914220052842011
#   :	:
#   (107573, 1073)	0.10826778934491357
#   (107573, 1122)	0.10512442839824397
#   (107573, 97)	0.10648060943070506
#   (107573, 48)	0.1519191726826684
# ...

# %%
vectorizer.get_feature_names_out().shape
# Out:
# (1202,)
